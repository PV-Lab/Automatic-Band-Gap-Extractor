# %% [markdown]
# ## Example usage of the Automatic Band Gap Extractor package
#
# #### The "data" input should be in the format of an (n x m) pandas array with n reflectance data points and (m - 1) measured spectra, where m = 0 is the wavelength
#
# Package written by Alexander (Aleks) E. Siemenn <asiemenn@mit.edu>, 05 Feb. 2023

# %%
import os
import pandas as pd
import extractor

# %%
datapath = os.getcwd() + '\\example-data\\'
data = pd.read_csv(datapath + 'example-data.csv')
display(data) # diaply of sample data input format with labeled headers for each measured sample and wavelength values in the first column
# Out:
#      wavelength    AF_CsPbI3  AF_FA0.25Cs0.75PbI3  AF_FA0.5Cs0.5PbI3  \
# 0        381.51   970.354566           945.403898         1029.46670
# 1        383.52   907.761376           885.985078         1028.32390
# 2        385.52   810.450654           795.486380          905.35950
# 3        387.53   724.277324           725.004706          825.99524
# 4        389.54   650.933808           662.319820          762.34045
# ..          ...          ...                  ...                ...
# 295     1010.14  1201.668080          1095.065980         1156.35720
# 296     1012.40  1218.232480          1109.244320         1147.01670
# 297     1014.66  1237.413100          1125.175800         1164.40480
# 298     1016.92  1222.677160          1121.025120         1155.05710
# 299     1019.18  1218.914760          1114.489320         1138.70470
#
#      AF_FA0.75Cs0.25PbI3    AF_FAPbI3  TF_Cs0.25FA0.75PbI3  TF_Cs0.5FA0.5PbI3  \
# ...

# %%
extractor.autoextract(data=data, csvname='example-output',
                      savepath=datapath+'example-output\\', verbose=True)
# Out:
#           AF_CsPbI3  AF_FA0.25Cs0.75PbI3  AF_FA0.5Cs0.5PbI3  \
# bandgap0   2.565967             2.539522           2.461486
# bandgap1        NaN                  NaN                NaN
#
#           AF_FA0.75Cs0.25PbI3  AF_FAPbI3  TF_Cs0.25FA0.75PbI3  \
# bandgap0             1.957749   1.475363             1.935364
# bandgap1             1.457192        NaN             1.459119
#
#           TF_Cs0.5FA0.5PbI3  TF_Cs0.75FA0.25PbI3  TF_CsPbI3_avg  \
# bandgap0            2.57313             2.594015       2.506282
# bandgap1                NaN                  NaN            NaN
#
#           TF_CsPbI3_black phase  TF_CsPbI3_yellow phase  TF_FAPbI3
# bandgap0               1.970377                2.589251   2.580392
# bandgap1               1.643893                     NaN        NaN
